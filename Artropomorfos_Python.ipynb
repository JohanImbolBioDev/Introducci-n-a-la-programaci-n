# %% [markdown]
# <a href="https://colab.research.google.com/github/JohanImbolBioDev/Introducci-n-a-la-programaci-n/blob/main/Artropomorfos_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python es una calculadora...

# %% [markdown]
# ## Suma

# %% [markdown]
# ## Resta

# %% [markdown]
# ## Multiplicar

# %% [markdown]
# ## Potencia

# %% [markdown]
# ## Dividir

# %% [markdown]
# ## Residuo

# %% [markdown]
# #Variables

# %% [markdown]
# # Imprimir un mensaje

# %% [markdown]
# Desarrollar un programa que pregunte un nombre y muestre el mensaje indicado abajo
#
# ```python
#  #Entrada   Digite su nombre: Johan
#  #Salida  Johan vas a pasar zoologia de artropodos (tal vez)
# ```

# %% [markdown]
# Cantidad de letras de un string

# %% [markdown]
#  **Problema**
#
#  Desarrolle un programa que muestre el mensaje:
#
#
# 'Hola,
#
#
# mi artrópodo favorito es ...'
#
# (Pseudocodigo)

# %% [markdown]
# Desarrolle un programa que ejecute la siguiente ecuación
#
# $$
# y = 5x + 7
# $$
#
# (Pseudocodigo)

# %% [markdown]
# **Nota**
# Siempre desarrolle el pseudocodigo

# %% [markdown]
# **Problema**
# Desarrolle un programa que calcule el número total de patas de un grupo de insectos, considerando que cada insecto tiene 6 patas. El usuario debe depositar la cantidad de insectos.

# %% [markdown]
# **Problema**
# En fisiología animal, especialmente en artrópodos y mamíferos, una estimación importante es la superficie corporal (SA), que se relaciona con procesos como la pérdida de calor, intercambio de gases y tasa metabólica.
#
# Una fórmula empírica para estimar la superficie corporal en función del volumen (V) es:
# $$
#  SA = a ⋅ V^{2/3}
# $$

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# > Kühsel, Sara, et al. “Surface Area-Volume Ratios in Insects.” Insect Science, vol. 24, no. 5, 15 Aug. 2016, pp. 829–841, https://doi.org/10.1111/1744-7917.12362.

# %% [markdown]
# ## Listas

# %% [markdown]
# Cree una lista con ordenes de artropoda

# %%
Ordenes = ['Coleoptera', 'lepidoptera', 'Psocoptera', 'Polydesmida', 'Amblypygi']

# %% [markdown]
# Mostar el segundo orden

# %% [markdown]
# Mostrar tods a partir del segundo

# %% [markdown]
# Mostrar los 3 primeros

# %% [markdown]
# Agregue un valor al final de la lista

# %% [markdown]
# Elimine el tercer orden

# %% [markdown]
# Actualice un orden

# %% [markdown]
# Muestre el siguiente mensaje: Hay {cantidad} {insecto} en la colección

# %%
insectos = [
    ["Coleoptera", 5],
    ["Lepidoptera", 9]
]

# %% [markdown]
# ## Condicionales

# %%
7==9
7>=9
7<=9
7!=9
and
or

# %%
nombre = "libélula"
vuela = True

if vuela:
    print(f"{nombre} puede volar.")
else:
    print(f"{nombre} no puede volar.")

# %% [markdown]
# **Problema**
#
# Desarrolle un programa que solicite al usuario el número de patas de un artrópodo
# y determine si se trata de un insecto (6 patas), un arácnido (8 patas)
# u otro tipo de artrópodo.

# %% [markdown]
# ##Ciclos

# %% [markdown]
# Escriba los numeros del .... en 10 segundos

# %% [markdown]
# Desarrolle un programa que recorra una lista de insectos
# y muestre un mensaje para cada uno diciendo:
#
# Entrada
#
# insectos = ["libélula", "escarabajo", "hormiga"]
#
# "{insecto} fue observado en el campo".

# %% [markdown]
# **Problema**
#
# Calcule la superficie corporal de los siguientes lepidopteras, dado los siguientes volumenes:

# %%
Volumenes = [50, 100, 150, 250, 300] #mm³

# %% [markdown]
# **Problema**
#
# Durante una salida de campo, un biólogo observa insectos y los registra uno por uno.
# Desarrolle un programa que pregunte al usuario si ha observado otro insecto
# y repita la pregunta hasta que la respuesta sea "no".
# Al final, el programa debe mostrar cuántos insectos fueron registrados.

# %% [markdown]
# ## Descargue el siguiente archivo
# https://datadryad.org/dataset/doi:10.5061/dryad.kh1893243
#
#
#
# > Sosiak, Christine E, and Phillip Barden. “Multidimensional Trait Morphology Predicts Ecology across Ant Lineages.” Functional Ecology, vol. 35, no. 1, 23 Oct. 2020, pp. 139–152, https://doi.org/10.1111/1365-2435.13697.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel('/content/FESosiakSA1.xlsx')

# %%
plt.rcParams.update({
    'axes.edgecolor': 'black',
    'axes.facecolor': 'white',
    'axes.grid': True,
    'grid.color': 'lightgray',
    'grid.linestyle': '--',
    'axes.spines.top': False,
    'axes.spines.right': False,
    'axes.spines.left': False,
    'axes.spines.bottom': False,
    'xtick.bottom': False,
    'ytick.left': False,
})

# %% [markdown]
# Observe como son los datos

# %% [markdown]
# ¿Qué columnas hay?

# %% [markdown]
# Tome solo las columnas morfologicas

# %% [markdown]
# Realice una grafica de dispersión

# %% [markdown]
# Realice un boxplot

# %%
sns.boxplot(data=df, x= 'nest_niche', y= 'head_length')

# %%
from sklearn.decomposition import PCA

morfologia = df.iloc[:,3:8]
